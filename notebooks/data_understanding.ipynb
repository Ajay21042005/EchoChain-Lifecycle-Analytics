# %%
import pandas as pd

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\acer\OneDrive\Desktop\EchoChain-Lifecycle-Analytics\notebooks

# %%
olx = pd.read_excel("../data/raw/olx_dataset.xlsx")

ebay = pd.read_csv(
    "../data/raw/ebay_products.csv",
    engine="python",
    on_bad_lines="skip"
)

used = pd.read_csv("../data/raw/used_devices.csv")

print("OLX:", olx.shape)
print("eBay:", ebay.shape)
print("Used:", used.shape)
# Out:
# OLX: (3931, 11)
# eBay: (17577, 30)
# Used: (3454, 15)

# %%
print("OLX")
display(olx.head())
print(" eBay ")
display(ebay.head())
print("Used Devices ")
display(used.head())
# Out:
# OLX
#    Unnamed: 0 categoryName            userName              dateJoined  \
# 0           0      Mobiles        Straight Way   Member since Dec 2015
# 1           1      Mobiles            Ali butt   Member since Dec 2020
# 2           2      Mobiles  Exit - Mobile Home   Member since Jan 2021
# 3           3      Mobiles            Ibraheem  Member since Sept 2022
# 4           4      Mobiles           Nouman Ch   Member since Dec 2018
#
#    location       price                                              title  \
# 0  Pakistan  Rs 115,000                                       iPhone 14 JV
# 1  Pakistan    Rs 9,999  OPPO A57 4+64 for sale with complete box . 033...
# 2  Pakistan  Rs 122,000                                Google Pixel 7 & 7A
# 3  Pakistan  Rs 215,000  Samsung Galaxy S24 Ultra                      ...
# 4  Pakistan   Rs 18,499  Samsung Tab A7 lite 3/32 LTE Data Sim Fresh Ge...
#
#           brand condition                                        description  \
# ...

# %%
print("OLX")
olx.info()
print("\n" + "="*50)
print("eBay")
ebay.info()
print("\n" + "="*50)
print("Used Devices")
used.info()
# Out:
# OLX
# <class 'pandas.DataFrame'>
# RangeIndex: 3931 entries, 0 to 3930
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    3931 non-null   int64
#  1   categoryName  3931 non-null   str
#  2   userName      3931 non-null   str
#  3   dateJoined    3931 non-null   str
#  4   location      3912 non-null   str
#  5   price         2758 non-null   str
#  6   title         3930 non-null   str
#  7   brand         2951 non-null   str
#  8   condition     2109 non-null   str
#  9   description   2979 non-null   str
#  10  adId          3931 non-null   str
# dtypes: int64(1), str(10)
# memory usage: 337.9 KB
#
# ...
# eBay
# <class 'pandas.DataFrame'>
# RangeIndex: 17577 entries, 0 to 17576
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Uniq Id                17577 non-null  str
# ...

# %%
print("OLX Missing Values")
print(olx.isnull().sum())
print("\n=========================\n")
print("eBay Missing Values")
print(ebay.isnull().sum())
print("\n=========================\n")
print("Used Devices Missing Values")
print(used.isnull().sum())
# Out:
# OLX Missing Values
# Unnamed: 0         0
# categoryName       0
# userName           0
# dateJoined         0
# location          19
# price           1173
# title              1
# brand            980
# condition       1822
# description      952
# adId               0
# dtype: int64
#
# ...
#
# eBay Missing Values
# Uniq Id                      0
# Crawl Timestamp              0
# Pageurl                      0
# Website                      0
# Title                       12
# Num Of Reviews           17577
# Average Rating           17577
# Number Of Ratings        17577
# Model Num                16220
# Sku                      17577
# Upc                      14484
# Manufacturer                 1
# Model Name                   0
# Price                      330
# Monthly Price            17577
# Stock                        0
# Carrier                  15782
# Color Category           14758
# Internal Memory          15159
# Screen Size              15825
# ...

# %%
print("OLX")
print(olx.describe())
print("\n=========================\n")
print("Used Devices")
print(used.describe())
# Out:
# OLX
#         Unnamed: 0
# count  3931.000000
# mean   1965.000000
# std    1134.926282
# min       0.000000
# 25%     982.500000
# 50%    1965.000000
# 75%    2947.500000
# max    3930.000000
#
# ...
#
# Used Devices
#        screen_size  main_camera_mp  selfie_camera_mp   int_memory  \
# count  3454.000000     3275.000000       3452.000000  3450.000000
# mean     13.713115        9.460208          6.554229    54.573099
# std       3.805280        4.815461          6.970372    84.972371
# min       5.080000        0.080000          0.000000     0.010000
# 25%      12.700000        5.000000          2.000000    16.000000
# 50%      12.830000        8.000000          5.000000    32.000000
# 75%      15.340000       13.000000          8.000000    64.000000
# max      30.710000       48.000000         32.000000  1024.000000
#
#                ram      battery       weight  release_year    days_used  \
# count  3450.000000  3448.000000  3447.000000   3454.000000  3454.000000
# ...
